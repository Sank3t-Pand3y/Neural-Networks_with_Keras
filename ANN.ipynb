# %% [markdown]
# <a href="https://colab.research.google.com/github/Sank3t-Pand3y/Neural-Networks_with_Keras/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


weights = np.around(np.random.uniform(size=6), decimals = 2) # initialize the weights
biases = np.around(np.random.uniform(size=3), decimals=2) # initialize the biases

# %%
print(weights)
print(biases)
# Out:
# [0.67 0.59 0.09 0.31 0.92 0.17]
# [0.74 0.77 0.21]

# %% [markdown]
# <img src="http://cocl.us/neural_network_example" alt="Neural Network Example" width="600px">

# %%
x_1 = 0.5   # This is input 1
x_2 = 0.85 # input 2

print('x1 is {} and x2 is {}'.format(x_1, x_2))
# Out:
# x1 is 0.5 and x2 is 0.85

# %%
z_11 = x_1 * weights[0] + x_2 * weights[1] + biases[0]

print('The weighted sum of the inputs at the first node in the hidden layer is {}'.format(z_11))
# Out:
# The weighted sum of the inputs at the first node in the hidden layer is 1.5765

# %%
z_12 = x_1 * weights[2] + x_2 * weights[3] + biases[1]

print('The weighted sum of the inputs at the second node in the hidden layer is {}'.format(z_12))
# Out:
# The weighted sum of the inputs at the second node in the hidden layer is 1.0785

# %%
a_11 = 1.0 / (1 + np.exp(-z_11))

print("The activation of the first node in the hidden layer is {}".format(np.around(a_11, decimals = 4)))
# Out:
# The activation of the first node in the hidden layer is 0.8287

# %%
a_12 = 1.0 /(1.0 + np.exp(-z_12))

print('The activation function of the second node in the hidden layer is {}'.format(np.around(a_12 , decimals = 4)))
# Out:
# The activation function of the second node in the hidden layer is 0.7462

# %%
z_2  = a_11 * weights[4] + a_12 * weights[5] + biases[2]

print('The weighted sum of the inputs at the output layer is {}'.format(np.around(z_2, decimals = 4)))
# Out:
# The weighted sum of the inputs at the output layer is 1.0993

# %%
a_2 = 1.0 / (1.0 + np.exp(-z_2))

print('The output of the network for x1 = 0.5 and x2 = 0.85 is {}'.format(np.around(a_2, decimals = 4)))
# Out:
# The output of the network for x1 = 0.5 and x2 = 0.85 is 0.7501

# %% [markdown]
# ## Now Building a Neural Network.

# %%
n = 2 # number of inputs
num_hidden_layers = 2 # number of hidden layers
m = [2, 2] # number of nodes in each hidden layer
num_nodes_output = 1 # number of nodes in the output layer

# %% [markdown]
# Now that we defined the structure of the network, let's go ahead and inititailize the weights and the biases in the network to random numbers. In order to be able to initialize the weights and the biases to random numbers, we will need to import the **Numpy** library.

# %%
n = 2 ## This is the Number of inputs.
num_hidden_layers = 2 ## Number of hidden layers
m = [2,2] ## The number of nodes or neuron in each hidden layer .i.e Hidden layer 1 has 2 node and hidden layer 2 has 2 node.
num_nodes_output = 1  ## The number of nodes in the output layer

# %%
import numpy as np

num_nodes_previous  = n    ## The number of nodes in the previouus layer. For example :- For hidden layer 1 we have num_nodes_previous = 2 because there are 2 input layers.

network = {}   ## Initialize the network as an empty dictionary

## Note : We have num_hidden_layers = 2 and add 1, we get value = 3. So the loop will be for 3 times.
for layer in range(num_hidden_layers + 1):

  ## Determine the name of layer
  if layer == num_hidden_layers:
    layer_name = 'output'
    num_nodes = num_nodes_output
  else:
    layer_name = 'layer_{}'.format(layer + 1)
    num_nodes = m[layer]


  ## We initialize the weights and biases associated with each node in the current layer
  network[layer_name] = {}
  for node in range(num_nodes):
    node_name = 'node_{}'.format(node + 1)
    network[layer_name][node_name] = {
        'weights' : np.around(np.random.uniform(size = num_nodes_previous), decimals = 2),
        'bias' : np.around(np.random.uniform(size = 1), decimals = 2)
    }

  num_nodes_previous = num_nodes  # For the next layer, the current layer will become the previous layer


print(network)  ## We are printing the Network
# Out:
# {'layer_1': {'node_1': {'weights': array([0.13, 0.73]), 'bias': array([0.91])}, 'node_2': {'weights': array([0.66, 0.85]), 'bias': array([0.51])}}, 'layer_2': {'node_1': {'weights': array([0.07, 0.26]), 'bias': array([0.82])}, 'node_2': {'weights': array([0.51, 0.66]), 'bias': array([0.84])}}, 'output': {'node_1': {'weights': array([0.94, 0.4 ]), 'bias': array([0.71])}}}

# %%
import pandas as pd

df = pd.DataFrame(network)

df
# Out:
#                                           layer_1  \
# node_1  {'weights': [0.13, 0.73], 'bias': [0.91]}
# node_2  {'weights': [0.66, 0.85], 'bias': [0.51]}
#
#                                           layer_2  \
# node_1  {'weights': [0.07, 0.26], 'bias': [0.82]}
# node_2  {'weights': [0.51, 0.66], 'bias': [0.84]}
#
#                                           output
# node_1  {'weights': [0.94, 0.4], 'bias': [0.71]}
# node_2                                       NaN

# %% [markdown]
# ## Note : We can create a function of the above code so that we are able to repetitively execute all this code whenever we want to construct a Neural Network.

# %%
def initialize_network(num_inputs, num_hidden_layers, num_nodes_hidden, num_nodes_output):

  num_nodes_previous = num_inputs

  network = {}

  for layer in range(num_hidden_layers + 1):

    # Determine the name of the layer
    if layer == num_hidden_layers:
      layer_name = 'Output'
      num_nodes = num_nodes_output
    else:
      layer_name = 'layer_{}'.format(layer + 1)
      num_nodes = num_nodes_hidden[layer]


    ## We initialize the Weights and Bias for each node
    network[layer_name] = {}
    for node in range(num_nodes):
      node_name = 'node_{}'.format(node + 1)
      network[layer_name][node_name] = {
          'weights' : np.around(np.random.uniform(size=num_nodes_previous),decimals = 2),
          'bias' : np.around(np.random.uniform(size= 1), decimals = 2),
      }

    num_nodes_previous = num_nodes

  return network

# %%
small_network = initialize_network(5,3,[3,2,3],1)

# %% [markdown]
# ## The above code has build a network architecture.

# %% [markdown]
# ## Now We have to Compute Weighted Sum at each Node.
#
# The weighted sum at each node is computed as the dot product of the inputs and the weights plus the bias. So let's create a function called *compute_weighted_sum* that does just that.

# %%
def compute_weighted_sum(inputs, weights, bias):
  return np.sum(inputs * weights) + bias

# %%
from random import seed

np.random.seed(12)

inputs = np.around(np.random.uniform(size =5), decimals=2)


print('The inputs to the Network are {}'.format(inputs))
# Out:
# The inputs to the Network are [0.15 0.74 0.26 0.53 0.01]

# %% [markdown]
# ## Now we use compute_weighted_sum function to calculate the weighted sum at the first node in the first hiddne layer.

# %%
node_weights = small_network['layer_1']['node_1']['weights']
node_bias = small_network['layer_1']['node_1']['bias']

weighted_sum = compute_weighted_sum(inputs, node_weights, node_bias)

print('The weighted sum at the first node in the hidden layer is {}'.format(np.around(weighted_sum[0],decimals = 4 )))
# Out:
# The weighted sum at the first node in the hidden layer is 1.0698

# %% [markdown]
# ## For the Activation Function.

# %%
def node_activation(weighted_sum):
  return 1.0 / (1.0 + np.exp(-1 * weighted_sum))

# %% [markdown]
# ## Now we use node_activation function to compute the output of the first node in the first hidden layer.

# %%
node_output = node_activation(compute_weighted_sum(inputs, node_weights, node_bias))

print('The output of the first node in the hidden layer is {}'.format(np.around(node_output[0], decimals = 4)))
# Out:
# The output of the first node in the hidden layer is 0.7446

# %% [markdown]
# ## Till Now we have Obtain the Output of the first hidden layer Node_1.
#
# Which mean we have obtain the Weight and activation value of the Hidden layer 1 node_1.

# %% [markdown]
# ## Forward Propagation

# %% [markdown]
# The final piece of building a neural network that can perform predictions is to put everything together. So let's create a function that applies the *compute_weighted_sum* and *node_activation* functions to each node in the network and propagates the data all the way to the output layer and outputs a prediction for each node in the output layer.

# %% [markdown]
# The way we are going to accomplish this is through the following procedure:
#
# 1. Start with the input layer as the input to the first hidden layer.
# 2. Compute the weighted sum at the nodes of the current layer.
# 3. Compute the output of the nodes of the current layer.
# 4. Set the output of the current layer to be the input to the next layer.
# 5. Move to the next layer in the network.
# 6. Repeat steps 2 - 5 until we compute the output of the output layer.

# %%
def forward_propagate(network, inputs):

    layer_inputs = list(inputs) # start with the input layer as the input to the first hidden layer

    for layer in network:

        layer_data = network[layer]

        layer_outputs = []
        for layer_node in layer_data:

            node_data = layer_data[layer_node]

            # compute the weighted sum and the output of each node at the same time
            node_output = node_activation(compute_weighted_sum(layer_inputs, node_data['weights'], node_data['bias']))
            layer_outputs.append(np.around(node_output[0], decimals=4))

        if layer != 'output':
            print('The outputs of the nodes in hidden layer number {} is {}'.format(layer.split('_')[1], layer_outputs))

        layer_inputs = layer_outputs # set the output of this layer to be the input to next layer

    network_predictions = layer_outputs
    return network_predictions

# %% [markdown]
# #### Use the *forward_propagate* function to compute the prediction of our small network

# %%
predictions = forward_propagate(small_network ,inputs)
print('The predicted value by the network for the given input is {}'.format(np.around(predictions[0], decimals=4)))
# Out:
# The outputs of the nodes in hidden layer number 1 is [np.float64(0.7446), np.float64(0.822), np.float64(0.7922)]
# The outputs of the nodes in hidden layer number 2 is [np.float64(0.9327), np.float64(0.8403)]
# The outputs of the nodes in hidden layer number 3 is [np.float64(0.8058), np.float64(0.639), np.float64(0.8533)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-4220064829.py in <cell line: 0>()
# ----> 1 predictions = forward_propagate(small_network ,inputs)
#       2 print('The predicted value by the network for the given input is {}'.format(np.around(predictions[0], decimals=4)))
#
# /tmp/ipython-input-1281548230.py in forward_propagate(network, inputs)
#      17
#      18         if layer != 'output':
# ---> 19             print('The outputs of the nodes in hidden layer number {} is {}'.format(layer.split('_')[1], layer_outputs))
#      20
# ...
